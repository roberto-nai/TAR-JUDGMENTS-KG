# %% [markdown]
# """
# 01_judgments_list.ipynb
# """

# %%
### IMPORT ###
from pathlib import Path
from typing import List
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import openai
from openai import OpenAI
import os
import csv

# %%
### LOCAL IMPORT ###
from config import config_reader
from utilities import create_directory_with_gitkeep

# %%
### GLOBALS ###
yaml_config = config_reader.config_read_yaml("config.yml", "config")

# OpenAI
openai.api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# inputs
judgments_raw_dir = str(yaml_config["JUDGMENTS_RAW_DIR"])
judgments_ext = str(yaml_config["JUDGMENTS_EXT"])
starting_pqm_markers = ['PQM', 'P.Q.M.', 'pqm', 'p.q.m.']

# outputs
judgments_clean_dir = str(yaml_config["JUDGMENTS_CLEAN_DIR"])
pqm_file_texts = str(yaml_config["PQM_FILE_TEXTS"])
pqm_file_labels = str(yaml_config["PQM_FILE_LABELS"])

# %% [markdown]
# # Functions

# %%
def get_files_with_extension(directory: str, extension: str) -> List[str]:
    """
    Retrieve all files with the specified extension from the given directory using pathlib.

    Args:
        directory (str): The path of the directory in which to search for files.
        extension (str): The file extension to filter by (e.g. '.txt').

    Returns:
        List[str]: A list containing the full paths of the files with the given extension.
    """
    path = Path(directory)
    return [str(file) for file in path.rglob(f"*{extension}") if file.is_file()]

# %%
def extract_paragraphs(file_path: str, starting_markers: list) -> list:
    """Extract non-empty paragraph texts from an HTML file.

    This function utilises BeautifulSoup to parse the HTML file located at the given file path.
    It returns a list of strings corresponding to the text content of each non-empty <p> element
    that is found after the first occurrence of a <p> element with the class "fatto" whose text matches
    any of the provided starting markers (excluded) and before the first occurrence of a <p> element
    with the class "tabula" (also excluded).

    Args:
        file_path (str): The path to the HTML file.
        starting_markers (list): A list of strings considered as valid starting markers.

    Returns:
        list: A list of strings containing the extracted paragraph texts.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    # Locate the starting marker: a <p class="fatto"> element with text matching one of the starting markers.
    start_tag = None
    for tag in soup.find_all('p', class_='fatto'):
        text = tag.get_text(strip=True)
        if any(text == marker for marker in starting_markers):
            start_tag = tag
            break

    if start_tag is None:
        return []

    paragraphs = []
    # Iterate over subsequent <p> elements until a <p> with class "tabula" is found.
    for p_tag in start_tag.find_all_next('p'):
        if 'tabula' in p_tag.get('class', []):
            break
        text = p_tag.get_text(strip=True)
        if text:
            paragraphs.append(text)

    return paragraphs

# %%
def store_paragraphs_in_dataframe(file_path: str) -> pd.DataFrame:
    """Store the file name and extracted paragraphs in a pandas DataFrame.

    This function extracts paragraphs from the given HTML file using the extract_paragraphs function,
    then creates and returns a pandas DataFrame containing the file name (without the full path) and
    each extracted paragraph. If multiple paragraphs are extracted, each paragraph will be stored as a
    separate row in the DataFrame with the same file name.

    Args:
        file_path (str): The path to the HTML file.

    Returns:
        pd.DataFrame: A DataFrame with two columns: 'file_name' and 'paragraph'. Each row contains the
        file name and one of the extracted paragraphs.
    """
    file_name = Path(file_path).name
    data = [{'file_name': file_name, 'paragraph': paragraph} for paragraph in paragraphs]
    return pd.DataFrame(data)

# %%
def analyse_judgement(text: str) -> str:
    """Analyse the given judgement paragraph and determine whether the decision is 'accolta' or 'respinta'.

    If the text does not contain a clear decision (e.g. headers, notes, or lists of names),
    the function returns 'none'.

    Args:
        text (str): The paragraph text to analyse.

    Returns:
        str: 'accolta', 'respinta', or 'none' if no clear decision is present.
    """
    messages = [
        {
            "role": "system",
            "content": (
                "You are a legal expert. When provided with the text of a judgement, determine if the decision is "
                "'accolta' (granted) or 'respinta' (dismissed). If the text contains only non-decisive content such as "
                "headers, notes, lists of names, or procedural indications, respond exclusively with 'None'. "
                "Reply only with one of the following words: 'accolta', 'respinta', or 'None'."
            )
        },
        {
            "role": "user",
            "content": f"Please analyse the following judgement text:\n\n{text}"
        }
    ]

    try:
        response = client.chat.completions.create(model="gpt-3.5-turbo",
        messages=messages,
        temperature=0,
        max_tokens=10)
    except Exception as e:
        print("Error during API request:", e)
        return "Error"

    # print("Result:", response) # debug

    result = response.choices[0].message.content.strip().lower()

    if result in {"accolta", "respinta"}:
        return result
    else:
        return None

# %% [markdown]
# # Main

# %%
print()
print("*** PROGRAM START ***")
print()
# Out:
# *** PROGRAM START ***

# %%
start_time = datetime.now().replace(microsecond=0)
print("Start process:", str(start_time))
print()
# Out:
# Start process: 2025-02-04 14:47:27

# %%
print("Preparing outputs")
create_directory_with_gitkeep(judgments_clean_dir)
# Out:
# Preparing outputs
# Directory 'judgments_clean' and .gitkeep file created

# %%
output_file_path = Path(judgments_clean_dir) / pqm_file_labels
file_exists = output_file_path.exists()
with output_file_path.open(mode='a', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile, delimiter=";")
    # If the file does not exist, write the header row.
    if not file_exists:
        writer.writerow(["file_name", "label"])

# %%
print("> Listing file in TAR Judgments")
print("Directory:", judgments_raw_dir)
list_files = get_files_with_extension(judgments_raw_dir, judgments_ext)
list_files_len = len(list_files)
print("Files found:", list_files_len)
# Out:
# > Listing file in TAR Judgments
# Directory: judgments_raw
# Files found: 129

# %% [markdown]
# # PQM extraction

# %%
print("> Reading TAR Judgments file")
all_data = []
for count, judgment_file in enumerate(list_files, start=1):
    print(f"[{count} / {list_files_len}] - {judgment_file}")
    list_para = extract_paragraphs(judgment_file, starting_pqm_markers)
    file_name = Path(judgment_file).name # get only the file from complete path
    data = [{'file_name': file_name, 'paragraph': paragraph} for paragraph in list_para]
    all_data.extend(data)
df_judg = pd.DataFrame(all_data) # create an unique dataframe
# Out:
# > Reading TAR Judgments file
# [1 / 129] - judgments_raw/tar_to_202200005_01.html
# [2 / 129] - judgments_raw/tar_to_202200008_01.html
# [3 / 129] - judgments_raw/tar_to_202200023_20.html
# [4 / 129] - judgments_raw/tar_to_202200041_01.html
# [5 / 129] - judgments_raw/tar_to_202200042_01.html
# [6 / 129] - judgments_raw/tar_to_202200045_01.html
# [7 / 129] - judgments_raw/tar_to_202200046_01.html
# [8 / 129] - judgments_raw/tar_to_202200053_01.html
# [9 / 129] - judgments_raw/tar_to_202200055_01.html
# [10 / 129] - judgments_raw/tar_to_202200056_01.html
# [11 / 129] - judgments_raw/tar_to_202200058_01.html
# [12 / 129] - judgments_raw/tar_to_202200061_01.html
# [13 / 129] - judgments_raw/tar_to_202200063_01.html
# [14 / 129] - judgments_raw/tar_to_202200077_20.html
# [15 / 129] - judgments_raw/tar_to_202200086_01.html
# [16 / 129] - judgments_raw/tar_to_202200091_01.html
# [17 / 129] - judgments_raw/tar_to_202200092_01.html
# [18 / 129] - judgments_raw/tar_to_202200116_20.html
# [19 / 129] - judgments_raw/tar_to_202200125_01.html
# [20 / 129] - judgments_raw/tar_to_202200126_01.html
# [21 / 129] - judgments_raw/tar_to_202200132_01.html
# [22 / 129] - judgments_raw/tar_to_202200154_01.html
# [23 / 129] - judgments_raw/tar_to_202200155_01.html
# [24 / 129] - judgments_raw/tar_to_202200160_01.html
# [25 / 129] - judgments_raw/tar_to_202200161_01.html
# [26 / 129] - judgments_raw/tar_to_202200165_01.html
# [27 / 129] - judgments_raw/tar_to_202200169_01.html
# [28 / 129] - judgments_raw/tar_to_202200170_01.html
# [29 / 129] - judgments_raw/tar_to_202200171_01.html
# [30 / 129] - judgments_raw/tar_to_202200173_01.html
# [31 / 129] - judgments_raw/tar_to_202200174_01.html
# [32 / 129] - judgments_raw/tar_to_202200178_01.html
# [33 / 129] - judgments_raw/tar_to_202200183_01.html
# [34 / 129] - judgments_raw/tar_to_202200185_20.html
# [35 / 129] - judgments_raw/tar_to_202200186_20.html
# [36 / 129] - judgments_raw/tar_to_202200187_20.html
# [37 / 129] - judgments_raw/tar_to_202200188_01.html
# [38 / 129] - judgments_raw/tar_to_202200189_01.html
# [39 / 129] - judgments_raw/tar_to_202200192_01.html
# [40 / 129] - judgments_raw/tar_to_202200207_01.html
# [41 / 129] - judgments_raw/tar_to_202200210_01.html
# [42 / 129] - judgments_raw/tar_to_202200213_01.html
# [43 / 129] - judgments_raw/tar_to_202200263_01.html
# [44 / 129] - judgments_raw/tar_to_202200295_20.html
# [45 / 129] - judgments_raw/tar_to_202200299_20.html
# [46 / 129] - judgments_raw/tar_to_202200308_01.html
# [47 / 129] - judgments_raw/tar_to_202200339_20.html
# [48 / 129] - judgments_raw/tar_to_202200360_01.html
# [49 / 129] - judgments_raw/tar_to_202200377_01.html
# [50 / 129] - judgments_raw/tar_to_202200398_20.html
# [51 / 129] - judgments_raw/tar_to_202200413_01.html
# [52 / 129] - judgments_raw/tar_to_202200418_01.html
# [53 / 129] - judgments_raw/tar_to_202200419_01.html
# [54 / 129] - judgments_raw/tar_to_202200428_01.html
# [55 / 129] - judgments_raw/tar_to_202200431_01.html
# [56 / 129] - judgments_raw/tar_to_202200436_01.html
# [57 / 129] - judgments_raw/tar_to_202200438_01.html
# [58 / 129] - judgments_raw/tar_to_202200451_01.html
# [59 / 129] - judgments_raw/tar_to_202200453_01.html
# [60 / 129] - judgments_raw/tar_to_202200462_01.html
# [61 / 129] - judgments_raw/tar_to_202200464_01.html
# [62 / 129] - judgments_raw/tar_to_202200484_01.html
# [63 / 129] - judgments_raw/tar_to_202200485_01.html
# [64 / 129] - judgments_raw/tar_to_202200503_01.html
# [65 / 129] - judgments_raw/tar_to_202200532_01.html
# [66 / 129] - judgments_raw/tar_to_202200541_01.html
# [67 / 129] - judgments_raw/tar_to_202200544_01.html
# [68 / 129] - judgments_raw/tar_to_202200546_01.html
# [69 / 129] - judgments_raw/tar_to_202200550_01.html
# [70 / 129] - judgments_raw/tar_to_202200555_01.html
# [71 / 129] - judgments_raw/tar_to_202200561_20.html
# [72 / 129] - judgments_raw/tar_to_202200597_01.html
# [73 / 129] - judgments_raw/tar_to_202200607_01.html
# [74 / 129] - judgments_raw/tar_to_202200611_01.html
# [75 / 129] - judgments_raw/tar_to_202200613_01.html
# [76 / 129] - judgments_raw/tar_to_202200616_20.html
# [77 / 129] - judgments_raw/tar_to_202200628_01.html
# [78 / 129] - judgments_raw/tar_to_202200632_01.html
# [79 / 129] - judgments_raw/tar_to_202200645_01.html
# [80 / 129] - judgments_raw/tar_to_202200661_01.html
# [81 / 129] - judgments_raw/tar_to_202200664_01.html
# [82 / 129] - judgments_raw/tar_to_202200681_01.html
# [83 / 129] - judgments_raw/tar_to_202200686_01.html
# [84 / 129] - judgments_raw/tar_to_202200687_01.html
# [85 / 129] - judgments_raw/tar_to_202200698_20.html
# [86 / 129] - judgments_raw/tar_to_202200700_20.html
# [87 / 129] - judgments_raw/tar_to_202200702_01.html
# [88 / 129] - judgments_raw/tar_to_202200706_20.html
# [89 / 129] - judgments_raw/tar_to_202200717_01.html
# [90 / 129] - judgments_raw/tar_to_202200719_01.html
# [91 / 129] - judgments_raw/tar_to_202200739_01.html
# [92 / 129] - judgments_raw/tar_to_202200741_01.html
# [93 / 129] - judgments_raw/tar_to_202200766_01.html
# [94 / 129] - judgments_raw/tar_to_202200773_01.html
# [95 / 129] - judgments_raw/tar_to_202200801_01.html
# [96 / 129] - judgments_raw/tar_to_202200832_01.html
# [97 / 129] - judgments_raw/tar_to_202200835_01.html
# [98 / 129] - judgments_raw/tar_to_202200838_01.html
# [99 / 129] - judgments_raw/tar_to_202200841_01.html
# [100 / 129] - judgments_raw/tar_to_202200859_01.html
# [101 / 129] - judgments_raw/tar_to_202200863_01.html
# [102 / 129] - judgments_raw/tar_to_202200883_01.html
# [103 / 129] - judgments_raw/tar_to_202200884_01.html
# [104 / 129] - judgments_raw/tar_to_202200897_01.html
# [105 / 129] - judgments_raw/tar_to_202200898_01.html
# [106 / 129] - judgments_raw/tar_to_202200907_01.html
# [107 / 129] - judgments_raw/tar_to_202200918_01.html
# [108 / 129] - judgments_raw/tar_to_202200933_01.html
# [109 / 129] - judgments_raw/tar_to_202200941_20.html
# [110 / 129] - judgments_raw/tar_to_202200971_01.html
# [111 / 129] - judgments_raw/tar_to_202200987_01.html
# [112 / 129] - judgments_raw/tar_to_202200994_01.html
# [113 / 129] - judgments_raw/tar_to_202201019_01.html
# [114 / 129] - judgments_raw/tar_to_202201021_20.html
# [115 / 129] - judgments_raw/tar_to_202201047_01.html
# [116 / 129] - judgments_raw/tar_to_202201053_01.html
# [117 / 129] - judgments_raw/tar_to_202201072_01.html
# [118 / 129] - judgments_raw/tar_to_202201088_01.html
# [119 / 129] - judgments_raw/tar_to_202201094_01.html
# [120 / 129] - judgments_raw/tar_to_202201095_01.html
# [121 / 129] - judgments_raw/tar_to_202201096_01.html
# [122 / 129] - judgments_raw/tar_to_202201104_01.html
# [123 / 129] - judgments_raw/tar_to_202201105_01.html
# [124 / 129] - judgments_raw/tar_to_202201109_20.html
# [125 / 129] - judgments_raw/tar_to_202201167_01.html
# [126 / 129] - judgments_raw/tar_to_202201185_01.html
# [127 / 129] - judgments_raw/tar_to_202201201_01.html
# [128 / 129] - judgments_raw/tar_to_202201213_01.html
# [129 / 129] - judgments_raw/tar_to_202201218_01.html

# %%
df_judg.head(10)
# Out:
#                   file_name                                          paragraph
# 0  tar_to_202200005_01.html  Il Tribunale Amministrativo Regionale per il P...
# 1  tar_to_202200005_01.html                                  Spese compensate.
# 2  tar_to_202200005_01.html  Ordina che la presente sentenza sia eseguita d...
# 3  tar_to_202200005_01.html  Così deciso in Torino nella camera di consigli...
# 4  tar_to_202200005_01.html  Gianluca Bellucci,\tPresidenteSilvia Cattaneo,...
# 5  tar_to_202200008_01.html  Il Tribunale Amministrativo Regionale per il P...
# 6  tar_to_202200008_01.html  Condanna la società ricorrente alla rifusione ...
# 7  tar_to_202200008_01.html  Ordina che la presente sentenza sia eseguita d...
# 8  tar_to_202200008_01.html  Così deciso in Torino nella camera di consigli...
# 9  tar_to_202200008_01.html  Vincenzo Salamone,\tPresidenteFlavia Risso,\tP...

# %%
print("> Saving")
path_out = Path(judgments_clean_dir) / pqm_file_texts
print("Path:", path_out)
df_judg.to_csv(path_out, sep=";", index=False, quoting=csv.QUOTE_MINIMAL)
# Out:
# > Saving
# Path: judgments_clean/pqm_texts.csv

# %%
# Labelling phase
# Iterate over each row in the DataFrame.
count = 0
df_judg_len = len(df_judg)
if df_judg_len > 0:
    for _, row in df_judg.iterrows():
        count+=1
        file_name = row["file_name"]
        paragraph = row["paragraph"]
        result = analyse_judgement(paragraph)
        print(f"[{count} / {df_judg_len}] Result ({file_name}): {result}")
        # Only append the row if a clear decision is detected.
        if result != None:
            with output_file_path.open(mode='a', newline='', encoding='utf-8') as csvfile:
                writer = csv.writer(csvfile, delimiter=";")
                writer.writerow([file_name, result])
# Out:
# Result (tar_to_202200005_01.html): respinta respinta
# Result (tar_to_202200005_01.html): None None
# Result (tar_to_202200005_01.html): None None
# Result (tar_to_202200005_01.html): None None
# Result (tar_to_202200005_01.html): None None
# Result (tar_to_202200008_01.html): respinta respinta
# Result (tar_to_202200008_01.html): accolta accolta
# Result (tar_to_202200008_01.html): None None
# Result (tar_to_202200008_01.html): None None
# Result (tar_to_202200008_01.html): None None
# Result (tar_to_202200023_20.html): respinta respinta
# Result (tar_to_202200023_20.html): None None
# Result (tar_to_202200023_20.html): None None
# Result (tar_to_202200023_20.html): None None
# Result (tar_to_202200023_20.html): None None
# Result (tar_to_202200041_01.html): respinta respinta
# Result (tar_to_202200041_01.html): respinta respinta
# Result (tar_to_202200041_01.html): None None
# Result (tar_to_202200041_01.html): None None
# Result (tar_to_202200041_01.html): None None
# Result (tar_to_202200042_01.html): respinta respinta
# Result (tar_to_202200042_01.html): None None
# Result (tar_to_202200042_01.html): None None
# Result (tar_to_202200042_01.html): None None
# Result (tar_to_202200042_01.html): None None
# Result (tar_to_202200045_01.html): respinta respinta
# Result (tar_to_202200045_01.html): accolta accolta
# Result (tar_to_202200045_01.html): None None
# Result (tar_to_202200045_01.html): None None
# Result (tar_to_202200045_01.html): None None
# Result (tar_to_202200046_01.html): respinta respinta
# Result (tar_to_202200046_01.html): accolta accolta
# Result (tar_to_202200046_01.html): None None
# Result (tar_to_202200046_01.html): None None
# Result (tar_to_202200046_01.html): None None
# Result (tar_to_202200053_01.html): accolta accolta
# Result (tar_to_202200053_01.html): accolta accolta
# Result (tar_to_202200053_01.html): accolta accolta
# Result (tar_to_202200053_01.html): accolta accolta
# Result (tar_to_202200053_01.html): None None
# Result (tar_to_202200053_01.html): None None
# Result (tar_to_202200053_01.html): None None
# Result (tar_to_202200053_01.html): None None
# Result (tar_to_202200053_01.html): None None
# Result (tar_to_202200055_01.html): respinta respinta
# Result (tar_to_202200055_01.html): accolta accolta
# Result (tar_to_202200055_01.html): None None
# Result (tar_to_202200055_01.html): None None
# Result (tar_to_202200055_01.html): None None
# Result (tar_to_202200056_01.html): respinta respinta
# Result (tar_to_202200056_01.html): None None
# Result (tar_to_202200056_01.html): None None
# Result (tar_to_202200056_01.html): None None
# Result (tar_to_202200056_01.html): None None
# Result (tar_to_202200058_01.html): None None
# Result (tar_to_202200058_01.html): respinta respinta
# Result (tar_to_202200058_01.html): None None
# Result (tar_to_202200058_01.html): None None
# Result (tar_to_202200058_01.html): None None
# Result (tar_to_202200058_01.html): None None
# Result (tar_to_202200061_01.html): None None
# Result (tar_to_202200061_01.html): respinta respinta
# Result (tar_to_202200061_01.html): respinta respinta
# Result (tar_to_202200061_01.html): accolta accolta
# Result (tar_to_202200061_01.html): None None
# Result (tar_to_202200061_01.html): None None
# Result (tar_to_202200061_01.html): None None
# Result (tar_to_202200063_01.html): respinta respinta
# Result (tar_to_202200063_01.html): None None
# Result (tar_to_202200063_01.html): None None
# Result (tar_to_202200063_01.html): None None
# Result (tar_to_202200063_01.html): None None
# Result (tar_to_202200077_20.html): respinta respinta
# Result (tar_to_202200077_20.html): accolta accolta
# Result (tar_to_202200077_20.html): None None
# Result (tar_to_202200077_20.html): None None
# Result (tar_to_202200077_20.html): None None
# Result (tar_to_202200086_01.html): respinta respinta
# Result (tar_to_202200086_01.html): accolta accolta
# Result (tar_to_202200086_01.html): None None
# Result (tar_to_202200086_01.html): None None
# Result (tar_to_202200086_01.html): None None
# Result (tar_to_202200091_01.html): respinta respinta
# Result (tar_to_202200091_01.html): None None
# Result (tar_to_202200091_01.html): None None
# Result (tar_to_202200091_01.html): None None
# Result (tar_to_202200091_01.html): None None
# Result (tar_to_202200092_01.html): respinta respinta
# Result (tar_to_202200092_01.html): None None
# Result (tar_to_202200092_01.html): None None
# Result (tar_to_202200092_01.html): None None
# Result (tar_to_202200092_01.html): None None
# Result (tar_to_202200116_20.html): respinta respinta
# Result (tar_to_202200116_20.html): respinta respinta
# Result (tar_to_202200116_20.html): None None
# Result (tar_to_202200116_20.html): None None
# Result (tar_to_202200116_20.html): None None
# Result (tar_to_202200125_01.html): None None
# Result (tar_to_202200125_01.html): accolta accolta
# Result (tar_to_202200125_01.html): None None
# Result (tar_to_202200125_01.html): None None
# Result (tar_to_202200125_01.html): None None
# Result (tar_to_202200125_01.html): None None
# Result (tar_to_202200125_01.html): None None
# Result (tar_to_202200126_01.html): respinta respinta
# Result (tar_to_202200126_01.html): accolta accolta
# Result (tar_to_202200126_01.html): None None
# Result (tar_to_202200126_01.html): None None
# Result (tar_to_202200126_01.html): None None
# Result (tar_to_202200132_01.html): None None
# Result (tar_to_202200132_01.html): respinta respinta
# Result (tar_to_202200132_01.html): None None
# Result (tar_to_202200132_01.html): respinta respinta
# Result (tar_to_202200132_01.html): None None
# Result (tar_to_202200132_01.html): None None
# Result (tar_to_202200132_01.html): None None
# Result (tar_to_202200154_01.html): None None
# Result (tar_to_202200154_01.html): accolta accolta
# Result (tar_to_202200154_01.html): respinta respinta
# Result (tar_to_202200154_01.html): None None
# Result (tar_to_202200154_01.html): None None
# Result (tar_to_202200154_01.html): None None
# Result (tar_to_202200154_01.html): None None
# Result (tar_to_202200155_01.html): accolta accolta
# Result (tar_to_202200155_01.html): None None
# Result (tar_to_202200155_01.html): None None
# Result (tar_to_202200155_01.html): None None
# Result (tar_to_202200155_01.html): None None
# Result (tar_to_202200160_01.html): respinta respinta
# Result (tar_to_202200160_01.html): None None
# Result (tar_to_202200160_01.html): None None
# Result (tar_to_202200160_01.html): None None
# Result (tar_to_202200160_01.html): None None
# Result (tar_to_202200161_01.html): respinta respinta
# Result (tar_to_202200161_01.html): None None
# Result (tar_to_202200161_01.html): None None
# Result (tar_to_202200161_01.html): None None
# Result (tar_to_202200161_01.html): None None
# Result (tar_to_202200165_01.html): None None
# Result (tar_to_202200165_01.html): accolta accolta
# Result (tar_to_202200165_01.html): None None
# Result (tar_to_202200165_01.html): None None
# Result (tar_to_202200165_01.html): None None
# Result (tar_to_202200165_01.html): None None
# Result (tar_to_202200169_01.html): None None
# Result (tar_to_202200169_01.html): respinta respinta
# Result (tar_to_202200169_01.html): respinta respinta
# Result (tar_to_202200169_01.html): accolta accolta
# Result (tar_to_202200169_01.html): None None
# Result (tar_to_202200169_01.html): None None
# Result (tar_to_202200169_01.html): None None
# Result (tar_to_202200170_01.html): None None
# Result (tar_to_202200170_01.html): respinta respinta
# Result (tar_to_202200170_01.html): None None
# Result (tar_to_202200170_01.html): None None
# Result (tar_to_202200170_01.html): None None
# Result (tar_to_202200170_01.html): None None
# Result (tar_to_202200170_01.html): None None
# Result (tar_to_202200171_01.html): None None
# Result (tar_to_202200171_01.html): respinta respinta
# Result (tar_to_202200171_01.html): None None
# Result (tar_to_202200171_01.html): None None
# Result (tar_to_202200171_01.html): None None
# Result (tar_to_202200171_01.html): None None
# Result (tar_to_202200173_01.html): None None
# Result (tar_to_202200173_01.html): accolta accolta
# Result (tar_to_202200173_01.html): None None
# Result (tar_to_202200173_01.html): None None
# Result (tar_to_202200173_01.html): None None
# Result (tar_to_202200173_01.html): None None
# Result (tar_to_202200174_01.html): respinta respinta
# Result (tar_to_202200174_01.html): accolta accolta
# Result (tar_to_202200174_01.html): None None
# Result (tar_to_202200174_01.html): None None
# Result (tar_to_202200174_01.html): None None
# Result (tar_to_202200178_01.html): respinta respinta
# Result (tar_to_202200178_01.html): None None
# Result (tar_to_202200178_01.html): None None
# Result (tar_to_202200178_01.html): None None
# Result (tar_to_202200178_01.html): None None
# Result (tar_to_202200178_01.html): None None
# Result (tar_to_202200178_01.html): None None
# Result (tar_to_202200178_01.html): None None
# Result (tar_to_202200183_01.html): accolta accolta
# Result (tar_to_202200183_01.html): accolta accolta
# Result (tar_to_202200183_01.html): None None
# Result (tar_to_202200183_01.html): None None
# Result (tar_to_202200183_01.html): None None
# Result (tar_to_202200185_20.html): None None
# Result (tar_to_202200185_20.html): None None
# Result (tar_to_202200185_20.html): None None
# Result (tar_to_202200185_20.html): None None
# Result (tar_to_202200185_20.html): None None
# Result (tar_to_202200186_20.html): None None
# Result (tar_to_202200186_20.html): None None
# Result (tar_to_202200186_20.html): None None
# Result (tar_to_202200186_20.html): None None
# Result (tar_to_202200186_20.html): None None
# Result (tar_to_202200187_20.html): None None
# Result (tar_to_202200187_20.html): None None
# Result (tar_to_202200187_20.html): None None
# Result (tar_to_202200187_20.html): None None
# Result (tar_to_202200187_20.html): None None
# Result (tar_to_202200188_01.html): None None
# Result (tar_to_202200188_01.html): respinta respinta
# Result (tar_to_202200188_01.html): accolta accolta
# Result (tar_to_202200188_01.html): None None
# Result (tar_to_202200188_01.html): None None
# Result (tar_to_202200188_01.html): None None
# Result (tar_to_202200188_01.html): None None
# Result (tar_to_202200189_01.html): respinta respinta
# Result (tar_to_202200189_01.html): None None
# Result (tar_to_202200189_01.html): None None
# Result (tar_to_202200189_01.html): None None
# Result (tar_to_202200192_01.html): None None
# Result (tar_to_202200192_01.html): respinta respinta
# Result (tar_to_202200192_01.html): None None
# Result (tar_to_202200192_01.html): None None
# Result (tar_to_202200192_01.html): None None
# Result (tar_to_202200192_01.html): None None
# Result (tar_to_202200192_01.html): None None
# Result (tar_to_202200207_01.html): respinta respinta
# Result (tar_to_202200207_01.html): accolta accolta
# Result (tar_to_202200207_01.html): None None
# Result (tar_to_202200207_01.html): None None
# Result (tar_to_202200207_01.html): None None
# Result (tar_to_202200210_01.html): respinta respinta
# Result (tar_to_202200210_01.html): accolta accolta
# Result (tar_to_202200210_01.html): None None
# Result (tar_to_202200210_01.html): None None
# Result (tar_to_202200210_01.html): None None
# Result (tar_to_202200210_01.html): None None
# Result (tar_to_202200213_01.html): accolta accolta
# Result (tar_to_202200213_01.html): accolta accolta
# Result (tar_to_202200213_01.html): None None

# %%
end_time = datetime.now().replace(microsecond=0)
delta_time = end_time - start_time
total_seconds = int(delta_time.total_seconds())
minutes, seconds = divmod(total_seconds, 60)

print()
print("End process:", end_time)
print(f"Time to finish ({delta_time}): {minutes} minutes, {seconds} seconds")

# %%
print()
print("*** PROGRAM START ***")
print()
